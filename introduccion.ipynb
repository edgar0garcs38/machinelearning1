# %% [markdown]
# # ITQ
# # PAO 2025-2026
# **Nombre:** *Edgar Garces* <br>
# **Fecha:** *07/01/2026*

# %% [markdown]
# ## INTRODUCCION A PYTHON
# Python es un lenguaje de programacion de alto nivel <br>
# Tambien python me permite desarrollar aplicaciones de escritorio y web

# %%
# Aqui va un comentario
print("hola mundo")
# Out:
# hola mundo
